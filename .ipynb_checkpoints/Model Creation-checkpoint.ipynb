# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
import tensorflow as tf
import os
import tensorflow_decision_forests as tfdf

# %%
## Specify file name and directory for the dataset. ##
directory = './data/';
file = 'attrition.xlsx';

# %%
## Read file from the directory and transform into pandas dataframe ##
def read_data(file, directory):
    filename = directory + file;
    df = pd.read_excel(filename);
    
    return df;

# %%
## Read in the excel file into a pandas dataframe. ##
df = read_data(file, directory);

# %%
## Print dataframe. ##
df
# Out:
#       Age Attrition     BusinessTravel  DailyRate              Department  \
# 0      41       Yes      Travel_Rarely       1102                   Sales
# 1      49        No  Travel_Frequently        279  Research & Development
# 2      37       Yes      Travel_Rarely       1373  Research & Development
# 3      33        No  Travel_Frequently       1392  Research & Development
# 4      27        No      Travel_Rarely        591  Research & Development
# ...   ...       ...                ...        ...                     ...
# 1465   36        No  Travel_Frequently        884  Research & Development
# 1466   39        No      Travel_Rarely        613  Research & Development
# 1467   27        No      Travel_Rarely        155  Research & Development
# 1468   49        No  Travel_Frequently       1023                   Sales
# 1469   34        No      Travel_Rarely        628  Research & Development
#
#       DistanceFromHome  Education EducationField  EmployeeCount  \
# 0                    1          2  Life Sciences              1
# 1                    8          1  Life Sciences              1
# 2                    2          2          Other              1
# 3                    3          4  Life Sciences              1
# 4                    2          1        Medical              1
# ...                ...        ...            ...            ...
# 1465                23          2        Medical              1
# 1466                 6          1        Medical              1
# 1467                 4          3  Life Sciences              1
# 1468                 2          3        Medical              1
# 1469                 8          3        Medical              1
#
#       EmployeeNumber  ...  RelationshipSatisfaction StandardHours  \
# 0                  1  ...                         1            80
# 1                  2  ...                         4            80
# 2                  4  ...                         2            80
# 3                  5  ...                         3            80
# 4                  7  ...                         4            80
# ...              ...  ...                       ...           ...
# 1465            2061  ...                         3            80
# 1466            2062  ...                         1            80
# 1467            2064  ...                         2            80
# 1468            2065  ...                         4            80
# 1469            2068  ...                         1            80
#
#       StockOptionLevel  TotalWorkingYears  TrainingTimesLastYear  \
# 0                    0                  8                      0
# 1                    1                 10                      3
# 2                    0                  7                      3
# 3                    0                  8                      3
# 4                    1                  6                      3
# ...                ...                ...                    ...
# 1465                 1                 17                      3
# 1466                 1                  9                      5
# 1467                 1                  6                      0
# 1468                 0                 17                      3
# 1469                 0                  6                      3
#
#      WorkLifeBalance  YearsAtCompany YearsInCurrentRole  \
# 0                  1               6                  4
# 1                  3              10                  7
# 2                  3               0                  0
# 3                  3               8                  7
# 4                  3               2                  2
# ...              ...             ...                ...
# 1465               3               5                  2
# 1466               3               7                  7
# 1467               3               6                  2
# 1468               2               9                  6
# 1469               4               4                  3
#
#       YearsSinceLastPromotion  YearsWithCurrManager
# 0                           0                     5
# 1                           1                     7
# 2                           0                     0
# 3                           3                     0
# 4                           2                     2
# ...                       ...                   ...
# 1465                        0                     3
# 1466                        1                     7
# 1467                        0                     3
# 1468                        0                     8
# 1469                        1                     2
#
# [1470 rows x 35 columns]

# %%
## Instantiate new column names for each header. ##
new_columns = {
    "Age": "age",
    "Attrition": "attrition",
    "BusinessTravel": "travel",
    "DailyRate": "daily_rate",
    "Department": "department",
    "DistanceFromHome": "distance_home",
    "Education": "education",
    "EducationField": "education_field",
    "EmployeeCount": "emp_count",
    "EmployeeNumber": "emp_number",
    "EnvironmentSatisfaction": "env_satisfaction",
    "Gender": "gender",
    "HourlyRate": "hour_rate",
    "JobInvolvement": "job_involvement",
    "JobLevel": "job_level",
    "JobRole": "job_role",
    "JobSatisfaction": "job_satisfaction",
    "MaritalStatus": "marital_status",
    "MonthlyIncome": "monthly_income",
    "MonthlyRate": "month_rate",
    "NumCompaniesWorked": "companied_worked_number",
    "Over18": "over_18",
    "OverTime": "overtime",
    "PercentSalaryHike": "salary_hike",
    "PerformanceRating": "performance_rating",
    "RelationshipSatisfaction": "relationship_satisfaction",
    "StandardHours": "hours",
    "StockOptionLevel": "stock_option",
    "TotalWorkingYears": "total_working_yrs",
    "TrainingTimesLastYear": "training_times",
    "WorkLifeBalance": "wl_balance",
    "YearsAtCompany": "years_at_company",
    "YearsInCurrentRole": "years_current_role",
    "YearsSinceLastPromotion": "years_last_promotion",
    "YearsWithCurrManager": "years_current_manager",
};

# %%
## Rename dataframe column names to the better computable forms. ##
def column_renames(df, columns):
    new_df = df.rename(columns=columns);
    
    return new_df;

# %%
## Rename column names to the newly instantiated names. ##
df = column_renames(df, new_columns);

# %%
## Change String values into Integer ##
def str_to_int(df, column_name, true_value):
    for row, col in df.iterrows():
        df.at[row, column_name] = 1 if df.at[row, column_name] == true_value else 0;
        
    return df;

# %%
## Set Boolean dtype for columns with boolean values. Applying columns: Attrition, Over18, OverTime ##
df = str_to_int(df, 'attrition', "Yes");
df = str_to_int(df, 'overtime', "Yes");
df = str_to_int(df, 'over_18', "Y");

# %%
df
# Out:
#       age attrition             travel  daily_rate              department  \
# 0      41         1      Travel_Rarely        1102                   Sales
# 1      49         0  Travel_Frequently         279  Research & Development
# 2      37         1      Travel_Rarely        1373  Research & Development
# 3      33         0  Travel_Frequently        1392  Research & Development
# 4      27         0      Travel_Rarely         591  Research & Development
# ...   ...       ...                ...         ...                     ...
# 1465   36         0  Travel_Frequently         884  Research & Development
# 1466   39         0      Travel_Rarely         613  Research & Development
# 1467   27         0      Travel_Rarely         155  Research & Development
# 1468   49         0  Travel_Frequently        1023                   Sales
# 1469   34         0      Travel_Rarely         628  Research & Development
#
#       distance_home  education education_field  emp_count  emp_number  ...  \
# 0                 1          2   Life Sciences          1           1  ...
# 1                 8          1   Life Sciences          1           2  ...
# 2                 2          2           Other          1           4  ...
# 3                 3          4   Life Sciences          1           5  ...
# 4                 2          1         Medical          1           7  ...
# ...             ...        ...             ...        ...         ...  ...
# 1465             23          2         Medical          1        2061  ...
# 1466              6          1         Medical          1        2062  ...
# 1467              4          3   Life Sciences          1        2064  ...
# 1468              2          3         Medical          1        2065  ...
# 1469              8          3         Medical          1        2068  ...
#
#       relationship_satisfaction hours  stock_option  total_working_yrs  \
# 0                             1    80             0                  8
# 1                             4    80             1                 10
# 2                             2    80             0                  7
# 3                             3    80             0                  8
# 4                             4    80             1                  6
# ...                         ...   ...           ...                ...
# 1465                          3    80             1                 17
# 1466                          1    80             1                  9
# 1467                          2    80             1                  6
# 1468                          4    80             0                 17
# 1469                          1    80             0                  6
#
#       training_times wl_balance  years_at_company years_current_role  \
# 0                  0          1                 6                  4
# 1                  3          3                10                  7
# 2                  3          3                 0                  0
# 3                  3          3                 8                  7
# 4                  3          3                 2                  2
# ...              ...        ...               ...                ...
# 1465               3          3                 5                  2
# 1466               5          3                 7                  7
# 1467               0          3                 6                  2
# 1468               3          2                 9                  6
# 1469               3          4                 4                  3
#
#       years_last_promotion  years_current_manager
# 0                        0                      5
# 1                        1                      7
# 2                        0                      0
# 3                        3                      0
# 4                        2                      2
# ...                    ...                    ...
# 1465                     0                      3
# 1466                     1                      7
# 1467                     0                      3
# 1468                     0                      8
# 1469                     1                      2
#
# [1470 rows x 35 columns]

# %%
## Remove non-necessary columns. Applying columns: Employee Count, Employee Number ##
df = df.drop(['emp_count', 'emp_number'], axis = 1);

# %%
df
# Out:
#       age attrition             travel  daily_rate              department  \
# 0      41         1      Travel_Rarely        1102                   Sales
# 1      49         0  Travel_Frequently         279  Research & Development
# 2      37         1      Travel_Rarely        1373  Research & Development
# 3      33         0  Travel_Frequently        1392  Research & Development
# 4      27         0      Travel_Rarely         591  Research & Development
# ...   ...       ...                ...         ...                     ...
# 1465   36         0  Travel_Frequently         884  Research & Development
# 1466   39         0      Travel_Rarely         613  Research & Development
# 1467   27         0      Travel_Rarely         155  Research & Development
# 1468   49         0  Travel_Frequently        1023                   Sales
# 1469   34         0      Travel_Rarely         628  Research & Development
#
#       distance_home  education education_field  env_satisfaction  gender  ...  \
# 0                 1          2   Life Sciences                 2  Female  ...
# 1                 8          1   Life Sciences                 3    Male  ...
# 2                 2          2           Other                 4    Male  ...
# 3                 3          4   Life Sciences                 4  Female  ...
# 4                 2          1         Medical                 1    Male  ...
# ...             ...        ...             ...               ...     ...  ...
# 1465             23          2         Medical                 3    Male  ...
# 1466              6          1         Medical                 4    Male  ...
# 1467              4          3   Life Sciences                 2    Male  ...
# 1468              2          3         Medical                 4    Male  ...
# 1469              8          3         Medical                 2    Male  ...
#
#       relationship_satisfaction  hours  stock_option total_working_yrs  \
# 0                             1     80             0                 8
# 1                             4     80             1                10
# 2                             2     80             0                 7
# 3                             3     80             0                 8
# 4                             4     80             1                 6
# ...                         ...    ...           ...               ...
# 1465                          3     80             1                17
# 1466                          1     80             1                 9
# 1467                          2     80             1                 6
# 1468                          4     80             0                17
# 1469                          1     80             0                 6
#
#       training_times wl_balance  years_at_company  years_current_role  \
# 0                  0          1                 6                   4
# 1                  3          3                10                   7
# 2                  3          3                 0                   0
# 3                  3          3                 8                   7
# 4                  3          3                 2                   2
# ...              ...        ...               ...                 ...
# 1465               3          3                 5                   2
# 1466               5          3                 7                   7
# 1467               0          3                 6                   2
# 1468               3          2                 9                   6
# 1469               3          4                 4                   3
#
#       years_last_promotion years_current_manager
# 0                        0                     5
# 1                        1                     7
# 2                        0                     0
# 3                        3                     0
# 4                        2                     2
# ...                    ...                   ...
# 1465                     0                     3
# 1466                     1                     7
# 1467                     0                     3
# 1468                     0                     8
# 1469                     1                     2
#
# [1470 rows x 33 columns]

# %%
## Change String values into integer for better computation. Applying columns: BusinessTravel, Department,
## EducationField, Gender, JobRole, MaritalStatus

## - Find value instances, assign corresponding numbers.

##============= BusinessTravel =============##
travel_resp = list(set(df['travel'])); ## Non-Travel -> 0, Travel_Rarely -> 1, Travel_Frequently -> 2.

##============= Department =============##
department_resp = list(set(df['department'])); ## Sales -> 0, Research & Development -> 1, Human Resources -> 2.

##============= EducationField =============##
education_resp = list(set(df['education_field'])); ## Life Science -> 0, Medical -> 1, Technical Degree -> 2, Marketing -> 3, Human Resources -> 4, Other -> 5.

##============= Gender =============##
gender_resp = list(set(df['gender'])); ## Female -> 0, Male -> 1.

##============= JobRole =============##
job_resp = list(set(df['job_role'])); ## Laboratory Technician -> 0, Healthcare Representative -> 1, Manager -> 2, Sales Representative -> 3, Research Director -> 4, Manufacturing Director -> 5, Human Resources -> 6, Research Scientist -> 7, Sales Executive -> 8.

##============= MaritalStatus =============##
marital_resp = list(set(df['marital_status'])); ## Single -> 0, Married -> 1, Divorced -> 2.


## - Transform string values into integer values as assigned from the above.
for row, col in df.iterrows():
    df.at[row, 'travel'] = 0 if df.at[row, 'travel'] == "Non-Travel" else 1 if df.at[row, 'travel'] == "Travel_Rarely" else 2;
    df.at[row, 'department'] = 0 if df.at[row, 'department'] == "Sales" else 1 if df.at[row, 'department'] == "Research & Development" else 2;
    df.at[row, 'education_field'] = 0 if df.at[row, 'education_field'] == "Life Science" else 1 if df.at[row, 'education_field'] == "Medical" else 2 if df.at[row, 'education_field'] == "Technical Degree" else 3 if df.at[row, 'education_field'] == "Marketing" else 4 if df.at[row, 'education_field'] == "Human Resources" else 5;
    df.at[row, 'gender'] = 0 if df.at[row, 'gender'] == "Female" else 1;
    df.at[row, 'job_role'] = 0 if df.at[row, 'job_role'] == "Laboratory Technician" else 1 if df.at[row, 'job_role'] == "Healthcare Representative" else 2 if df.at[row, 'job_role'] == "Manager" else 3 if df.at[row, 'job_role'] == "Sales Representative" else 4 if df.at[row, 'job_role'] == "Research Director" else 5 if df.at[row, 'job_role'] == "Manufacturing Director" else 6 if df.at[row, 'job_role'] == "Human Resources" else 7 if df.at[row, 'job_role'] == "Research Scientist" else 8;
    df.at[row, 'marital_status'] = 0 if df.at[row, 'marital_status'] == "Single" else 1 if df.at[row, 'marital_status'] == "Married" else 2;

# %%
df
# Out:
#       age attrition travel  daily_rate department  distance_home  education  \
# 0      41         1      1        1102          0              1          2
# 1      49         0      2         279          1              8          1
# 2      37         1      1        1373          1              2          2
# 3      33         0      2        1392          1              3          4
# 4      27         0      1         591          1              2          1
# ...   ...       ...    ...         ...        ...            ...        ...
# 1465   36         0      2         884          1             23          2
# 1466   39         0      1         613          1              6          1
# 1467   27         0      1         155          1              4          3
# 1468   49         0      2        1023          0              2          3
# 1469   34         0      1         628          1              8          3
#
#      education_field  env_satisfaction gender  ...  relationship_satisfaction  \
# 0                  5                 2      0  ...                          1
# 1                  5                 3      1  ...                          4
# 2                  5                 4      1  ...                          2
# 3                  5                 4      0  ...                          3
# 4                  1                 1      1  ...                          4
# ...              ...               ...    ...  ...                        ...
# 1465               1                 3      1  ...                          3
# 1466               1                 4      1  ...                          1
# 1467               5                 2      1  ...                          2
# 1468               1                 4      1  ...                          4
# 1469               1                 2      1  ...                          1
#
#       hours  stock_option total_working_yrs  training_times wl_balance  \
# 0        80             0                 8               0          1
# 1        80             1                10               3          3
# 2        80             0                 7               3          3
# 3        80             0                 8               3          3
# 4        80             1                 6               3          3
# ...     ...           ...               ...             ...        ...
# 1465     80             1                17               3          3
# 1466     80             1                 9               5          3
# 1467     80             1                 6               0          3
# 1468     80             0                17               3          2
# 1469     80             0                 6               3          4
#
#       years_at_company  years_current_role  years_last_promotion  \
# 0                    6                   4                     0
# 1                   10                   7                     1
# 2                    0                   0                     0
# 3                    8                   7                     3
# 4                    2                   2                     2
# ...                ...                 ...                   ...
# 1465                 5                   2                     0
# 1466                 7                   7                     1
# 1467                 6                   2                     0
# 1468                 9                   6                     0
# 1469                 4                   3                     1
#
#      years_current_manager
# 0                        5
# 1                        7
# 2                        0
# 3                        0
# 4                        2
# ...                    ...
# 1465                     3
# 1466                     7
# 1467                     3
# 1468                     8
# 1469                     2
#
# [1470 rows x 33 columns]

# %%
## Dimension of the dataframe. Row -> 1470, Column -> 33. ##
row_count = len(df);
column_count = len(df.columns);

# %%
## Copy the dataframe. ##
df_copy = df.copy();

# %%
## Shuffle the dataframe. ##
shuffled_df = df_copy.sample(frac = True);

# %%
## Set up a parameter for training and testing dataset split. ##
TRAIN_SPLIT = 0.8;

## Determine the index of training and testing dataset to split the dataframe. ##
training_size = int(TRAIN_SPLIT * row_count);

## Split the dataset into training and testing. ##
train_df, test_df = shuffled_df[:training_size], shuffled_df[training_size:];

# %%
## Convert the pandas dataframe into a Tensorflow dataset. ##
train_ds = tfdf.keras.pd_dataframe_to_tf_dataset(train_df, label="attrition");
test_ds = tfdf.keras.pd_dataframe_to_tf_dataset(test_df, label="attrition");

# %%
## Train a random forest model. ##
model = tfdf.keras.RandomForestModel(compute_oob_variable_importances=True);
model.fit(train_ds);
# Out:
# Use /var/folders/zr/gckyky6n2flg70m13x7tptjh0000gn/T/tmpzoq50259 as temporary training directory
# Reading training dataset...
# Training dataset read in 0:00:00.178594. Found 1176 examples.
# Training model...
# Model trained in 0:00:00.500971
# Compiling model...
# [INFO 23-08-19 16:18:30.3692 PDT kernel.cc:1243] Loading model from path /var/folders/zr/gckyky6n2flg70m13x7tptjh0000gn/T/tmpzoq50259/model/ with prefix 87b721545e4a405e
# [INFO 23-08-19 16:18:30.4287 PDT decision_forest.cc:660] Model loaded with 300 root(s), 48594 node(s), and 30 input feature(s).
# [INFO 23-08-19 16:18:30.4288 PDT abstract_model.cc:1312] Engine "RandomForestOptPred" built
# [INFO 23-08-19 16:18:30.4288 PDT kernel.cc:1075] Use fast generic engine
# Model compiled.

# %%
## Pull out a model summary for model structure evaluation. ##
model.summary();
# Out:
# Model: "random_forest_model_3"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
# =================================================================
# Total params: 1 (1.00 Byte)
# Trainable params: 0 (0.00 Byte)
# Non-trainable params: 1 (1.00 Byte)
# _________________________________________________________________
# Type: "RANDOM_FOREST"
# Task: CLASSIFICATION
# Label: "__LABEL"
#
# Input Features (32):
# 	age
# 	companied_worked_number
# 	daily_rate
# 	department
# 	distance_home
# 	education
# 	education_field
# 	env_satisfaction
# 	gender
# 	hour_rate
# 	hours
# 	job_involvement
# 	job_level
# 	job_role
# 	job_satisfaction
# 	marital_status
# 	month_rate
# 	monthly_income
# 	over_18
# 	overtime
# 	performance_rating
# 	relationship_satisfaction
# 	salary_hike
# 	stock_option
# 	total_working_yrs
# 	training_times
# 	travel
# 	wl_balance
# 	years_at_company
# 	years_current_manager
# 	years_current_role
# 	years_last_promotion
#
# No weights
#
# Variable Importance: INV_MEAN_MIN_DEPTH:
#     1.                  "overtime"  0.192592 ################
#     2.            "monthly_income"  0.184365 ##############
#     3.         "total_working_yrs"  0.158616 #########
#     4.          "years_at_company"  0.152215 #######
#     5.                       "age"  0.144884 ######
#     6.              "stock_option"  0.144540 ######
#     7.             "distance_home"  0.143161 #####
#     8.     "years_current_manager"  0.135306 ####
#     9.                "daily_rate"  0.132016 ###
#    10.                 "job_level"  0.130549 ###
#    11.        "years_current_role"  0.129578 ###
#    12.                "month_rate"  0.127808 ##
#    13.                 "hour_rate"  0.127788 ##
#    14.          "env_satisfaction"  0.127620 ##
#    15.          "job_satisfaction"  0.127601 ##
#    16.      "years_last_promotion"  0.127136 ##
#    17.            "marital_status"  0.126043 ##
#    18.           "job_involvement"  0.125700 ##
#    19.                    "travel"  0.125379 ##
#    20.               "salary_hike"  0.125205 ##
#    21.   "companied_worked_number"  0.124869 ##
#    22.                  "job_role"  0.124332 #
#    23. "relationship_satisfaction"  0.121874 #
#    24.                "wl_balance"  0.121275 #
#    25.            "training_times"  0.120812 #
#    26.                "department"  0.120204 #
#    27.           "education_field"  0.118885
#    28.                 "education"  0.117305
#    29.                    "gender"  0.116066
#    30.        "performance_rating"  0.114882
#
# Variable Importance: MEAN_DECREASE_IN_ACCURACY:
#     1.                  "overtime"  0.017007 ################
#     2.            "monthly_income"  0.014456 #############
#     3.          "years_at_company"  0.011054 ##########
#     4.                 "job_level"  0.010204 #########
#     5.     "years_current_manager"  0.009354 ########
#     6.         "total_working_yrs"  0.009354 ########
#     7.                       "age"  0.007653 #######
#     8.                "daily_rate"  0.005952 #####
#     9.                    "travel"  0.005952 #####
#    10.                  "job_role"  0.005952 #####
#    11.                 "hour_rate"  0.005102 ####
#    12.        "years_current_role"  0.004252 ####
#    13.                "month_rate"  0.003401 ###
#    14.             "distance_home"  0.003401 ###
#    15.            "training_times"  0.003401 ###
#    16.              "stock_option"  0.003401 ###
#    17.          "env_satisfaction"  0.003401 ###
#    18.                 "education"  0.002551 ##
#    19.                "wl_balance"  0.002551 ##
#    20.          "job_satisfaction"  0.002551 ##
#    21.           "education_field"  0.002551 ##
#    22. "relationship_satisfaction"  0.002551 ##
#    23.            "marital_status"  0.001701 #
#    24.   "companied_worked_number"  0.000850
#    25.                    "gender"  0.000850
#    26.           "job_involvement"  0.000850
#    27.               "salary_hike"  0.000850
#    28.                     "hours"  0.000000
#    29.        "performance_rating"  0.000000
#    30.                "department"  0.000000
#    31.                   "over_18"  0.000000
#    32.      "years_last_promotion"  0.000000
#
# Variable Importance: MEAN_DECREASE_IN_AP_2_VS_OTHERS:
#     1.                  "overtime"  0.121437 ################
#     2.                    "travel"  0.016316 ####
#     3.             "distance_home"  0.015139 ####
#     4.          "env_satisfaction"  0.012428 ####
#     5.          "job_satisfaction"  0.009141 ###
#     6.            "monthly_income"  0.006132 ###
#     7.                 "job_level"  0.005312 ###
#     8.      "years_last_promotion"  0.004051 ###
#     9. "relationship_satisfaction"  0.003063 ##
#    10.              "stock_option"  0.002703 ##
#    11.                "department"  0.001871 ##
#    12.                "wl_balance"  0.001080 ##
#    13.               "salary_hike"  0.000559 ##
#    14.                 "hour_rate"  0.000549 ##
#    15.        "performance_rating"  0.000252 ##
#    16.                    "gender"  0.000243 ##
#    17.                "daily_rate"  0.000168 ##
#    18.     "years_current_manager"  0.000025 ##
#    19.                   "over_18"  0.000000 ##
#    20.                     "hours"  0.000000 ##
#    21.           "education_field" -0.000707 ##
#    22.   "companied_worked_number" -0.000745 ##
#    23.            "marital_status" -0.001027 ##
#    24.           "job_involvement" -0.001230 ##
#    25.                  "job_role" -0.001510 ##
#    26.            "training_times" -0.001691 ##
#    27.                 "education" -0.002514 ##
#    28.        "years_current_role" -0.003794 ##
#    29.                "month_rate" -0.004999 ##
#    30.                       "age" -0.005068 ##
#    31.          "years_at_company" -0.023149
#    32.         "total_working_yrs" -0.024014
#
# Variable Importance: MEAN_DECREASE_IN_AUC_2_VS_OTHERS:
#     1.                  "overtime"  0.059203 ################
#     2.             "distance_home"  0.009706 ####
#     3.          "env_satisfaction"  0.008505 ###
#     4.              "stock_option"  0.006813 ###
#     5.          "job_satisfaction"  0.006670 ###
#     6. "relationship_satisfaction"  0.003418 ##
#     7.            "monthly_income"  0.002857 ##
#     8.                "department"  0.002820 ##
#     9.        "years_current_role"  0.002174 ##
#    10.                  "job_role"  0.002064 ##
#    11.            "marital_status"  0.002056 ##
#    12.                    "travel"  0.001866 ##
#    13.                 "job_level"  0.000959 ##
#    14.   "companied_worked_number"  0.000954 ##
#    15.                       "age"  0.000888 ##
#    16.                "month_rate"  0.000662 #
#    17.                "wl_balance"  0.000435 #
#    18.        "performance_rating"  0.000079 #
#    19.                     "hours"  0.000000 #
#    20.                   "over_18"  0.000000 #
#    21.                    "gender" -0.000169 #
#    22.               "salary_hike" -0.000580 #
#    23.            "training_times" -0.001239 #
#    24.           "education_field" -0.001257 #
#    25.                 "education" -0.001476 #
#    26.      "years_last_promotion" -0.001924 #
#    27.           "job_involvement" -0.001940 #
#    28.          "years_at_company" -0.002704 #
#    29.                "daily_rate" -0.003176 #
#    30.     "years_current_manager" -0.005147
#    31.         "total_working_yrs" -0.006365
#    32.                 "hour_rate" -0.007559
#
# Variable Importance: MEAN_DECREASE_IN_PRAUC_2_VS_OTHERS:
#     1.                  "overtime"  0.121103 ################
#     2.             "distance_home"  0.015579 ####
#     3.                    "travel"  0.015465 ####
#     4.          "env_satisfaction"  0.012263 ###
#     5.          "job_satisfaction"  0.008849 ###
#     6.                 "job_level"  0.005067 ###
#     7.            "monthly_income"  0.004955 ###
#     8.      "years_last_promotion"  0.003918 ###
#     9. "relationship_satisfaction"  0.003270 ##
#    10.              "stock_option"  0.002896 ##
#    11.                "department"  0.001824 ##
#    12.                "wl_balance"  0.000917 ##
#    13.               "salary_hike"  0.000613 ##
#    14.                 "hour_rate"  0.000392 ##
#    15.        "performance_rating"  0.000293 ##
#    16.                    "gender"  0.000051 ##
#    17.                "daily_rate"  0.000015 ##
#    18.                   "over_18"  0.000000 ##
#    19.                     "hours"  0.000000 ##
#    20.     "years_current_manager" -0.000247 ##
#    21.            "marital_status" -0.000732 ##
#    22.   "companied_worked_number" -0.000860 ##
#    23.           "job_involvement" -0.000935 ##
#    24.                  "job_role" -0.001252 ##
#    25.           "education_field" -0.001304 ##
#    26.            "training_times" -0.001604 ##
#    27.                 "education" -0.002640 ##
#    28.        "years_current_role" -0.003465 ##
#    29.                       "age" -0.004251 ##
#    30.                "month_rate" -0.004995 ##
#    31.          "years_at_company" -0.022831
#    32.         "total_working_yrs" -0.023444
#
# Variable Importance: NUM_AS_ROOT:
#     1.                  "overtime" 49.000000 ################
#     2.            "monthly_income" 48.000000 ###############
#     3.          "years_at_company" 44.000000 ##############
#     4.         "total_working_yrs" 37.000000 ############
#     5.                       "age" 21.000000 ######
#     6.     "years_current_manager" 21.000000 ######
#     7.                 "job_level" 18.000000 #####
#     8.              "stock_option" 17.000000 #####
#     9.        "years_current_role" 11.000000 ###
#    10.            "marital_status"  6.000000 #
#    11.             "distance_home"  5.000000 #
#    12.          "env_satisfaction"  5.000000 #
#    13.                    "travel"  5.000000 #
#    14.          "job_satisfaction"  4.000000 #
#    15.           "job_involvement"  2.000000
#    16. "relationship_satisfaction"  2.000000
#    17.                "daily_rate"  1.000000
#    18.                "department"  1.000000
#    19.                 "hour_rate"  1.000000
#    20.                "month_rate"  1.000000
#    21.                "wl_balance"  1.000000
#
# Variable Importance: NUM_NODES:
#     1.            "monthly_income" 1931.000000 ################
#     2.                "daily_rate" 1563.000000 ############
#     3.             "distance_home" 1502.000000 ############
#     4.                       "age" 1471.000000 ###########
#     5.                "month_rate" 1442.000000 ###########
#     6.                 "hour_rate" 1433.000000 ###########
#     7.         "total_working_yrs" 1091.000000 ########
#     8.               "salary_hike" 1057.000000 ########
#     9.          "years_at_company" 851.000000 ######
#    10.   "companied_worked_number" 833.000000 ######
#    11.                  "job_role" 830.000000 ######
#    12.          "job_satisfaction" 796.000000 ######
#    13.                  "overtime" 768.000000 #####
#    14.          "env_satisfaction" 762.000000 #####
#    15.      "years_last_promotion" 716.000000 #####
#    16. "relationship_satisfaction" 708.000000 #####
#    17.        "years_current_role" 674.000000 #####
#    18.     "years_current_manager" 648.000000 ####
#    19.              "stock_option" 621.000000 ####
#    20.           "education_field" 595.000000 ####
#    21.            "training_times" 560.000000 ####
#    22.                 "education" 519.000000 ###
#    23.           "job_involvement" 464.000000 ###
#    24.            "marital_status" 451.000000 ###
#    25.                "wl_balance" 422.000000 ##
#    26.                 "job_level" 394.000000 ##
#    27.                    "travel" 348.000000 ##
#    28.                "department" 304.000000 #
#    29.                    "gender" 298.000000 #
#    30.        "performance_rating" 95.000000
#
# Variable Importance: SUM_SCORE:
#     1.            "monthly_income" 11487.408744 ################
#     2.                  "overtime" 8839.203378 ############
#     3.                       "age" 7456.521388 ##########
#     4.             "distance_home" 7314.388537 #########
#     5.                "daily_rate" 6659.621605 #########
#     6.         "total_working_yrs" 6584.481838 ########
#     7.                "month_rate" 5734.268432 #######
#     8.                 "hour_rate" 5607.844569 #######
#     9.          "years_at_company" 5078.201798 ######
#    10.               "salary_hike" 4228.267915 #####
#    11.              "stock_option" 3724.266276 ####
#    12.          "job_satisfaction" 3694.133921 ####
#    13.          "env_satisfaction" 3598.451620 ####
#    14.                  "job_role" 3540.244982 ####
#    15.     "years_current_manager" 3442.387644 ####
#    16.   "companied_worked_number" 3437.535752 ####
#    17.        "years_current_role" 3302.936043 ####
#    18.      "years_last_promotion" 3232.730230 ####
#    19. "relationship_satisfaction" 2856.741877 ###
#    20.                 "job_level" 2485.485770 ###
#    21.            "marital_status" 2380.394972 ##
#    22.           "education_field" 2196.895259 ##
#    23.           "job_involvement" 2119.073690 ##
#    24.            "training_times" 2069.453646 ##
#    25.                "wl_balance" 1882.075747 ##
#    26.                 "education" 1819.093530 ##
#    27.                    "travel" 1793.424019 ##
#    28.                "department" 1365.775326 #
#    29.                    "gender" 1074.888886
#    30.        "performance_rating" 402.610275
#
#
#
# Winner takes all: true
# Out-of-bag evaluation: accuracy:0.861395 logloss:0.387759
# Number of trees: 300
# Total number of nodes: 48594
#
# Number of nodes by tree:
# Count: 300 Average: 161.98 StdDev: 9.57007
# Min: 131 Max: 185 Ignored: 0
# ----------------------------------------------
# [ 131, 133)  1   0.33%   0.33%
# [ 133, 136)  0   0.00%   0.33%
# [ 136, 139)  1   0.33%   0.67%
# [ 139, 142)  3   1.00%   1.67% #
# [ 142, 144)  2   0.67%   2.33%
# [ 144, 147)  6   2.00%   4.33% #
# [ 147, 150) 13   4.33%   8.67% ###
# [ 150, 153) 13   4.33%  13.00% ###
# [ 153, 155) 17   5.67%  18.67% ###
# [ 155, 158) 50  16.67%  35.33% ##########
# [ 158, 161) 27   9.00%  44.33% #####
# [ 161, 164) 47  15.67%  60.00% #########
# [ 164, 166) 25   8.33%  68.33% #####
# [ 166, 169) 18   6.00%  74.33% ####
# [ 169, 172) 26   8.67%  83.00% #####
# [ 172, 175) 14   4.67%  87.67% ###
# [ 175, 177) 10   3.33%  91.00% ##
# [ 177, 180) 16   5.33%  96.33% ###
# [ 180, 183)  4   1.33%  97.67% #
# [ 183, 185]  7   2.33% 100.00% #
#
# Depth by leafs:
# Count: 24447 Average: 7.77875 StdDev: 2.21777
# Min: 2 Max: 15 Ignored: 0
# ----------------------------------------------
# [  2,  3)   39   0.16%   0.16%
# [  3,  4)  299   1.22%   1.38% #
# [  4,  5) 1041   4.26%   5.64% ##
# [  5,  6) 2283   9.34%  14.98% #####
# [  6,  7) 3568  14.59%  29.57% ########
# [  7,  8) 4371  17.88%  47.45% ##########
# [  8,  9) 4257  17.41%  64.87% ##########
# [  9, 10) 3431  14.03%  78.90% ########
# [ 10, 11) 2342   9.58%  88.48% #####
# [ 11, 12) 1459   5.97%  94.45% ###
# [ 12, 13)  753   3.08%  97.53% ##
# [ 13, 14)  368   1.51%  99.03% #
# [ 14, 15)  156   0.64%  99.67%
# [ 15, 15]   80   0.33% 100.00%
#
# Number of training obs by leaf:
# Count: 24447 Average: 14.4312 StdDev: 21.3865
# Min: 5 Max: 270 Ignored: 0
# ----------------------------------------------
# [   5,  18) 20148  82.42%  82.42% ##########
# [  18,  31)  1830   7.49%  89.90% #
# [  31,  44)   865   3.54%  93.44%
# [  44,  58)   519   2.12%  95.56%
# [  58,  71)   319   1.30%  96.87%
# [  71,  84)   219   0.90%  97.76%
# [  84,  98)   161   0.66%  98.42%
# [  98, 111)    96   0.39%  98.81%
# [ 111, 124)    66   0.27%  99.08%
# [ 124, 138)    79   0.32%  99.41%
# [ 138, 151)    42   0.17%  99.58%
# [ 151, 164)    26   0.11%  99.69%
# [ 164, 177)    25   0.10%  99.79%
# [ 177, 191)    19   0.08%  99.87%
# [ 191, 204)    15   0.06%  99.93%
# [ 204, 217)     7   0.03%  99.96%
# [ 217, 231)     6   0.02%  99.98%
# [ 231, 244)     1   0.00%  99.98%
# [ 244, 257)     2   0.01%  99.99%
# [ 257, 270]     2   0.01% 100.00%
#
# Attribute in nodes:
# 	1931 : monthly_income [NUMERICAL]
# 	1563 : daily_rate [NUMERICAL]
# 	1502 : distance_home [NUMERICAL]
# 	1471 : age [NUMERICAL]
# 	1442 : month_rate [NUMERICAL]
# 	1433 : hour_rate [NUMERICAL]
# 	1091 : total_working_yrs [NUMERICAL]
# 	1057 : salary_hike [NUMERICAL]
# 	851 : years_at_company [NUMERICAL]
# 	833 : companied_worked_number [NUMERICAL]
# 	830 : job_role [NUMERICAL]
# 	796 : job_satisfaction [NUMERICAL]
# 	768 : overtime [NUMERICAL]
# 	762 : env_satisfaction [NUMERICAL]
# 	716 : years_last_promotion [NUMERICAL]
# 	708 : relationship_satisfaction [NUMERICAL]
# 	674 : years_current_role [NUMERICAL]
# 	648 : years_current_manager [NUMERICAL]
# 	621 : stock_option [NUMERICAL]
# 	595 : education_field [NUMERICAL]
# 	560 : training_times [NUMERICAL]
# 	519 : education [NUMERICAL]
# 	464 : job_involvement [NUMERICAL]
# 	451 : marital_status [NUMERICAL]
# 	422 : wl_balance [NUMERICAL]
# 	394 : job_level [NUMERICAL]
# 	348 : travel [NUMERICAL]
# 	304 : department [NUMERICAL]
# 	298 : gender [NUMERICAL]
# 	95 : performance_rating [NUMERICAL]
#
# Attribute in nodes with depth <= 0:
# 	49 : overtime [NUMERICAL]
# 	48 : monthly_income [NUMERICAL]
# 	44 : years_at_company [NUMERICAL]
# 	37 : total_working_yrs [NUMERICAL]
# 	21 : years_current_manager [NUMERICAL]
# 	21 : age [NUMERICAL]
# 	18 : job_level [NUMERICAL]
# 	17 : stock_option [NUMERICAL]
# 	11 : years_current_role [NUMERICAL]
# 	6 : marital_status [NUMERICAL]
# 	5 : travel [NUMERICAL]
# 	5 : env_satisfaction [NUMERICAL]
# 	5 : distance_home [NUMERICAL]
# 	4 : job_satisfaction [NUMERICAL]
# 	2 : relationship_satisfaction [NUMERICAL]
# 	2 : job_involvement [NUMERICAL]
# 	1 : wl_balance [NUMERICAL]
# 	1 : month_rate [NUMERICAL]
# 	1 : hour_rate [NUMERICAL]
# 	1 : department [NUMERICAL]
# 	1 : daily_rate [NUMERICAL]
#
# Attribute in nodes with depth <= 1:
# 	130 : overtime [NUMERICAL]
# 	119 : monthly_income [NUMERICAL]
# 	102 : total_working_yrs [NUMERICAL]
# 	82 : years_at_company [NUMERICAL]
# 	69 : stock_option [NUMERICAL]
# 	60 : age [NUMERICAL]
# 	48 : years_current_manager [NUMERICAL]
# 	42 : job_level [NUMERICAL]
# 	29 : travel [NUMERICAL]
# 	28 : years_current_role [NUMERICAL]
# 	26 : distance_home [NUMERICAL]
# 	24 : marital_status [NUMERICAL]
# 	18 : job_satisfaction [NUMERICAL]
# 	16 : job_involvement [NUMERICAL]
# 	15 : job_role [NUMERICAL]
# 	11 : env_satisfaction [NUMERICAL]
# 	10 : hour_rate [NUMERICAL]
# 	10 : daily_rate [NUMERICAL]
# 	10 : companied_worked_number [NUMERICAL]
# 	9 : years_last_promotion [NUMERICAL]
# 	9 : month_rate [NUMERICAL]
# 	9 : department [NUMERICAL]
# 	7 : wl_balance [NUMERICAL]
# 	6 : relationship_satisfaction [NUMERICAL]
# 	4 : salary_hike [NUMERICAL]
# 	3 : training_times [NUMERICAL]
# 	2 : education_field [NUMERICAL]
# 	2 : education [NUMERICAL]
#
# Attribute in nodes with depth <= 2:
# 	246 : overtime [NUMERICAL]
# 	229 : monthly_income [NUMERICAL]
# 	174 : total_working_yrs [NUMERICAL]
# 	131 : age [NUMERICAL]
# 	119 : years_at_company [NUMERICAL]
# 	119 : stock_option [NUMERICAL]
# 	100 : distance_home [NUMERICAL]
# 	92 : years_current_manager [NUMERICAL]
# 	65 : marital_status [NUMERICAL]
# 	64 : travel [NUMERICAL]
# 	63 : job_level [NUMERICAL]
# 	62 : years_current_role [NUMERICAL]
# 	62 : daily_rate [NUMERICAL]
# 	57 : job_involvement [NUMERICAL]
# 	56 : job_role [NUMERICAL]
# 	55 : month_rate [NUMERICAL]
# 	49 : hour_rate [NUMERICAL]
# 	46 : job_satisfaction [NUMERICAL]
# 	38 : env_satisfaction [NUMERICAL]
# 	33 : years_last_promotion [NUMERICAL]
# 	33 : companied_worked_number [NUMERICAL]
# 	31 : relationship_satisfaction [NUMERICAL]
# 	27 : training_times [NUMERICAL]
# 	27 : department [NUMERICAL]
# 	25 : wl_balance [NUMERICAL]
# 	25 : salary_hike [NUMERICAL]
# 	12 : education [NUMERICAL]
# 	11 : education_field [NUMERICAL]
# 	5 : performance_rating [NUMERICAL]
# 	5 : gender [NUMERICAL]
#
# Attribute in nodes with depth <= 3:
# 	394 : monthly_income [NUMERICAL]
# 	351 : overtime [NUMERICAL]
# 	246 : age [NUMERICAL]
# 	243 : total_working_yrs [NUMERICAL]
# 	240 : distance_home [NUMERICAL]
# 	188 : daily_rate [NUMERICAL]
# 	178 : stock_option [NUMERICAL]
# 	176 : years_at_company [NUMERICAL]
# 	168 : month_rate [NUMERICAL]
# 	146 : hour_rate [NUMERICAL]
# 	140 : years_current_manager [NUMERICAL]
# 	125 : years_current_role [NUMERICAL]
# 	125 : job_satisfaction [NUMERICAL]
# 	125 : job_role [NUMERICAL]
# 	115 : env_satisfaction [NUMERICAL]
# 	114 : marital_status [NUMERICAL]
# 	111 : job_involvement [NUMERICAL]
# 	108 : travel [NUMERICAL]
# 	107 : job_level [NUMERICAL]
# 	102 : years_last_promotion [NUMERICAL]
# 	100 : companied_worked_number [NUMERICAL]
# 	99 : salary_hike [NUMERICAL]
# 	70 : relationship_satisfaction [NUMERICAL]
# 	69 : wl_balance [NUMERICAL]
# 	65 : training_times [NUMERICAL]
# 	63 : department [NUMERICAL]
# 	48 : education_field [NUMERICAL]
# 	37 : education [NUMERICAL]
# 	18 : gender [NUMERICAL]
# 	13 : performance_rating [NUMERICAL]
#
# Attribute in nodes with depth <= 5:
# 	974 : monthly_income [NUMERICAL]
# 	689 : distance_home [NUMERICAL]
# 	662 : age [NUMERICAL]
# 	624 : daily_rate [NUMERICAL]
# 	559 : overtime [NUMERICAL]
# 	558 : month_rate [NUMERICAL]
# 	539 : total_working_yrs [NUMERICAL]
# 	537 : hour_rate [NUMERICAL]
# 	405 : salary_hike [NUMERICAL]
# 	392 : years_at_company [NUMERICAL]
# 	347 : job_satisfaction [NUMERICAL]
# 	344 : env_satisfaction [NUMERICAL]
# 	336 : job_role [NUMERICAL]
# 	336 : companied_worked_number [NUMERICAL]
# 	323 : stock_option [NUMERICAL]
# 	308 : years_current_role [NUMERICAL]
# 	304 : years_last_promotion [NUMERICAL]
# 	293 : years_current_manager [NUMERICAL]
# 	276 : relationship_satisfaction [NUMERICAL]
# 	248 : marital_status [NUMERICAL]
# 	232 : job_involvement [NUMERICAL]
# 	221 : education_field [NUMERICAL]
# 	210 : training_times [NUMERICAL]
# 	209 : travel [NUMERICAL]
# 	206 : wl_balance [NUMERICAL]
# 	198 : job_level [NUMERICAL]
# 	191 : education [NUMERICAL]
# 	141 : department [NUMERICAL]
# 	105 : gender [NUMERICAL]
# 	49 : performance_rating [NUMERICAL]
#
# Condition type in nodes:
# 	24147 : HigherCondition
# Condition type in nodes with depth <= 0:
# 	300 : HigherCondition
# Condition type in nodes with depth <= 1:
# 	900 : HigherCondition
# Condition type in nodes with depth <= 2:
# 	2061 : HigherCondition
# Condition type in nodes with depth <= 3:
# 	4084 : HigherCondition
# Condition type in nodes with depth <= 5:
# 	10816 : HigherCondition
# Node format: NOT_SET
#
# Training OOB:
# 	trees: 1, Out-of-bag evaluation: accuracy:0.783529 logloss:7.80239
# 	trees: 11, Out-of-bag evaluation: accuracy:0.827586 logloss:5.44514
# 	trees: 25, Out-of-bag evaluation: accuracy:0.844255 logloss:1.9205
# 	trees: 36, Out-of-bag evaluation: accuracy:0.848639 logloss:1.37786
# 	trees: 47, Out-of-bag evaluation: accuracy:0.84949 logloss:1.01153
# 	trees: 58, Out-of-bag evaluation: accuracy:0.84949 logloss:0.815246
# 	trees: 72, Out-of-bag evaluation: accuracy:0.85119 logloss:0.672618
# 	trees: 88, Out-of-bag evaluation: accuracy:0.852891 logloss:0.554218
# 	trees: 99, Out-of-bag evaluation: accuracy:0.85034 logloss:0.526347
# 	trees: 113, Out-of-bag evaluation: accuracy:0.853741 logloss:0.498889
# 	trees: 127, Out-of-bag evaluation: accuracy:0.855442 logloss:0.469249
# 	trees: 143, Out-of-bag evaluation: accuracy:0.854592 logloss:0.439142
# 	trees: 153, Out-of-bag evaluation: accuracy:0.855442 logloss:0.412008
# 	trees: 164, Out-of-bag evaluation: accuracy:0.854592 logloss:0.411918
# 	trees: 174, Out-of-bag evaluation: accuracy:0.855442 logloss:0.412109
# 	trees: 185, Out-of-bag evaluation: accuracy:0.856293 logloss:0.411712
# 	trees: 200, Out-of-bag evaluation: accuracy:0.856293 logloss:0.385755
# 	trees: 210, Out-of-bag evaluation: accuracy:0.857993 logloss:0.387373
# 	trees: 227, Out-of-bag evaluation: accuracy:0.857993 logloss:0.38688
# 	trees: 237, Out-of-bag evaluation: accuracy:0.857993 logloss:0.387055
# 	trees: 251, Out-of-bag evaluation: accuracy:0.860544 logloss:0.387245
# 	trees: 265, Out-of-bag evaluation: accuracy:0.859694 logloss:0.386543
# 	trees: 281, Out-of-bag evaluation: accuracy:0.859694 logloss:0.386983
# 	trees: 291, Out-of-bag evaluation: accuracy:0.859694 logloss:0.387463
# 	trees: 300, Out-of-bag evaluation: accuracy:0.861395 logloss:0.387759

# %%
## Evaluate and inspect the model. ##
inspector = model.make_inspector();

# %%
# ?inspector.model_type

# %%
print("Model type:", inspector.model_type())
print("Number of trees:", inspector.num_trees())
print("Objective:", inspector.objective())
print("Input features:", inspector.features())
# Out:
# Model type: RANDOM_FOREST
# Number of trees: 300
# Objective: Classification(label=__LABEL, class=None, num_classes=2)
# Input features: ["age" (1; #1), "companied_worked_number" (1; #2), "daily_rate" (1; #3), "department" (1; #4), "distance_home" (1; #5), "education" (1; #6), "education_field" (1; #7), "env_satisfaction" (1; #8), "gender" (1; #9), "hour_rate" (1; #10), "hours" (1; #11), "job_involvement" (1; #12), "job_level" (1; #13), "job_role" (1; #14), "job_satisfaction" (1; #15), "marital_status" (1; #16), "month_rate" (1; #17), "monthly_income" (1; #18), "over_18" (1; #19), "overtime" (1; #20), "performance_rating" (1; #21), "relationship_satisfaction" (1; #22), "salary_hike" (1; #23), "stock_option" (1; #24), "total_working_yrs" (1; #25), "training_times" (1; #26), "travel" (1; #27), "wl_balance" (1; #28), "years_at_company" (1; #29), "years_current_manager" (1; #30), "years_current_role" (1; #31), "years_last_promotion" (1; #32)]

# %%
inspector.evaluation()
# Out:
# Evaluation(num_examples=1176, accuracy=0.8613945578231292, loss=0.38775891607562335, rmse=None, ndcg=None, aucs=None, auuc=None, qini=None)

# %%
print(f"Available variable importances:")
for importance in inspector.variable_importances().keys():
  print("\t", importance)
# Out:
# Available variable importances:
# 	 INV_MEAN_MIN_DEPTH
# 	 MEAN_DECREASE_IN_ACCURACY
# 	 MEAN_DECREASE_IN_AP_2_VS_OTHERS
# 	 NUM_NODES
# 	 MEAN_DECREASE_IN_PRAUC_2_VS_OTHERS
# 	 MEAN_DECREASE_IN_AUC_2_VS_OTHERS
# 	 SUM_SCORE
# 	 NUM_AS_ROOT

# %%
# Mean decrease in AUC of the class 1 vs the others.
inspector.variable_importances()["MEAN_DECREASE_IN_AUC_2_VS_OTHERS"]
# Out:
# [("overtime" (1; #20), 0.059203348109572396),
#  ("distance_home" (1; #5), 0.009706460607531997),
#  ("env_satisfaction" (1; #8), 0.008504683242059885),
#  ("stock_option" (1; #24), 0.006812707214354785),
#  ("job_satisfaction" (1; #15), 0.0066703914737080705),
#  ("relationship_satisfaction" (1; #22), 0.0034182132522327935),
#  ("monthly_income" (1; #18), 0.0028568567196759487),
#  ("department" (1; #4), 0.0028199600461746854),
#  ("years_current_role" (1; #31), 0.00217426825990108),
#  ("job_role" (1; #14), 0.002063578239397734),
#  ("marital_status" (1; #16), 0.0020556718093609483),
#  ("travel" (1; #27), 0.0018659174884968488),
#  ("job_level" (1; #13), 0.0009593135110346207),
#  ("companied_worked_number" (1; #2), 0.0009540425576766154),
#  ("age" (1; #1), 0.0008881556407127622),
#  ("month_rate" (1; #17), 0.00066150464634529),
#  ("wl_balance" (1; #28), 0.0004348536519798163),
#  ("performance_rating" (1; #21), 7.906430035942158e-05),
#  ("hours" (1; #11), 0.0),
#  ("over_18" (1; #19), 0.0),
#  ("gender" (1; #9), -0.00016867050743363254),
#  ("salary_hike" (1; #23), -0.0005798048693060887),
#  ("training_times" (1; #26), -0.0012386740389730422),
#  ("education_field" (1; #7), -0.0012571223757237293),
#  ("education" (1; #6), -0.0014758669400530833),
#  ("years_last_promotion" (1; #32), -0.0019238979754266916),
#  ("job_involvement" (1; #12), -0.001939710835498487),
#  ("years_at_company" (1; #29), -0.002703999072310781),
#  ("daily_rate" (1; #3), -0.00317574939779397),
#  ("years_current_manager" (1; #30), -0.00514708595343516),
#  ("total_working_yrs" (1; #25), -0.006364676178979289),
#  ("hour_rate" (1; #10), -0.007558547114416392)]

# %%
import matplotlib.pyplot as plt

plt.figure(figsize=(12, 4))

# Mean decrease in AUC of the class 1 vs the others.
variable_importance_metric = "MEAN_DECREASE_IN_AUC_2_VS_OTHERS"
variable_importances = inspector.variable_importances()[variable_importance_metric]

# Extract the feature name and importance values.
#
# `variable_importances` is a list of <feature, importance> tuples.
feature_names = [vi[0].name for vi in variable_importances]
feature_importances = [vi[1] for vi in variable_importances]
# The feature are ordered in decreasing importance value.
feature_ranks = range(len(feature_names))

bar = plt.barh(feature_ranks, feature_importances, label=[str(x) for x in feature_ranks])
plt.yticks(feature_ranks, feature_names)
plt.gca().invert_yaxis()

# TODO: Replace with "plt.bar_label()" when available.
# Label each bar with values
for importance, patch in zip(feature_importances, bar.patches):
  plt.text(patch.get_x() + patch.get_width(), patch.get_y(), f"{importance:.4f}", va="top")

plt.xlabel(variable_importance_metric)
plt.title("Mean decrease in AUC of the class 2 vs the others")
plt.tight_layout()
plt.show()

# %%
html = tfdf.model_plotter.plot_model(model, tree_idx=0, max_depth=3)

# %%
# Out:
# '\n<script src="https://d3js.org/d3.v6.min.js"></script>\n<div id="tree_plot_f1fb1ca69a7d4667ac24d2cd2b8b9b92"></div>\n<script>\n/*\n * Copyright 2021 Google LLC.\n * Licensed under the Apache License, Version 2.0 (the "License");\n * you may not use this file except in compliance with the License.\n * You may obtain a copy of the License at\n *\n *     https://www.apache.org/licenses/LICENSE-2.0\n *\n * Unless required by applicable law or agreed to in writing, software\n * distributed under the License is distributed on an "AS IS" BASIS,\n * WITHOUT WARRANTIES OR CONDITIONS OF ANY KIND, either express or implied.\n * See the License for the specific language governing permissions and\n * limitations under the License.\n */\n\n/**\n *  Plotting of decision trees generated by TF-DF.\n *\n *  A tree is a recursive structure of node objects.\n *  A node contains one or more of the following components:\n *\n *    - A value: Representing the output of the node. If the node is not a leaf,\n *      the value is only present for analysis i.e. it is not used for\n *      predictions.\n *\n *    - A condition : For non-leaf nodes, the condition (also known as split)\n *      defines a binary test to branch to the positive or negative child.\n *\n *    - An explanation: Generally a plot showing the relation between the label\n *      and the condition to give insights about the effect of the condition.\n *\n *    - Two children : For non-leaf nodes, the children nodes. The first\n *      children (i.e. "node.children[0]") is the negative children (drawn in\n *      red). The second children is the positive one (drawn in green).\n *\n */\n\n/**\n * Plots a single decision tree into a DOM element.\n * @param {!options} options Dictionary of configurations.\n * @param {!tree} raw_tree Recursive tree structure.\n * @param {string} canvas_id Id of the output dom element.\n */\nfunction display_tree(options, raw_tree, canvas_id) {\n  console.log(options);\n\n  // Determine the node placement.\n  const tree_struct = d3.tree().nodeSize(\n      [options.node_y_offset, options.node_x_offset])(d3.hierarchy(raw_tree));\n\n  // Boundaries of the node placement.\n  let x_min = Infinity;\n  let x_max = -x_min;\n  let y_min = Infinity;\n  let y_max = -x_min;\n\n  tree_struct.each(d => {\n    if (d.x > x_max) x_max = d.x;\n    if (d.x < x_min) x_min = d.x;\n    if (d.y > y_max) y_max = d.y;\n    if (d.y < y_min) y_min = d.y;\n  });\n\n  // Size of the plot.\n  const width = y_max - y_min + options.node_x_size + options.margin * 2;\n  const height = x_max - x_min + options.node_y_size + options.margin * 2 +\n      options.node_y_offset - options.node_y_size;\n\n  const plot = d3.select(canvas_id);\n\n  // Tool tip\n  options.tooltip = plot.append(\'div\')\n                        .attr(\'width\', 100)\n                        .attr(\'height\', 100)\n                        .style(\'padding\', \'4px\')\n                        .style(\'background\', \'#fff\')\n                        .style(\'box-shadow\', \'4px 4px 0px rgba(0,0,0,0.1)\')\n                        .style(\'border\', \'1px solid black\')\n                        .style(\'font-family\', \'sans-serif\')\n                        .style(\'font-size\', options.font_size)\n                        .style(\'position\', \'absolute\')\n                        .style(\'z-index\', \'10\')\n                        .attr(\'pointer-events\', \'none\')\n                        .style(\'display\', \'none\');\n\n  // Create canvas\n  const svg = plot.append(\'svg\').attr(\'width\', width).attr(\'height\', height);\n  const graph =\n      svg.style(\'overflow\', \'visible\')\n          .append(\'g\')\n          .attr(\'font-family\', \'sans-serif\')\n          .attr(\'font-size\', options.font_size)\n          .attr(\n              \'transform\',\n              () => `translate(${options.margin},${\n                  - x_min + options.node_y_offset / 2 + options.margin})`);\n\n  // Plot bounding box.\n  if ( ...

# %%
# index_resp = list(df.index);
# attrition_resp = list(df['attrition']);

# %%
# ## Set up a global model configuration parameter ##
# TRAIN_SPLIT = 0.8;

# %%
# ## Create a numpy array for each dependent and independent variable in association to the attrition outcome. ##
# month_age = pd.DataFrame({"attrition":df['attrition'], "age":df['age']}).to_numpy();

# %%
# ## Compute the size of the training and testing datasets. ##
# training_size = int(TRAIN_SPLIT * row_count);

# %%
# ## Run shuffling and random seed to ensure a reproducibility and split the data into training and validating dataset. ##
# np.random.shuffle(month_age);
# train_data, test_data = month_age[:training_size], month_age[training_size:];
